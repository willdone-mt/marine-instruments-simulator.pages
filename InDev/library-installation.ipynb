# %%
import tkinter as tk
tk._test()

# %%
pip install pyqt5
# Out:
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.9 MB 855.6 kB/s eta 0:00:08
#    ---- ----------------------------------- 0.8/6.9 MB 863.3 kB/s eta 0:00:08
#    ---- ----------------------------------- 0.8/6.9 MB 863.3 kB/s eta 0:00:08
#    ------ --------------------------------- 1.0/6.9 MB 869.6 kB/s eta 0:00:07
#    ------- -------------------------------- 1.3/6.9 MB 850.9 kB/s eta 0:00:07
#    ------- -------------------------------- 1.3/6.9 MB 850.9 kB/s eta 0:00:07
#    --------- ------------------------------ 1.6/6.9 MB 820.8 kB/s eta 0:00:07
#    --------- ------------------------------ 1.6/6.9 MB 820.8 kB/s eta 0:00:07
# ...

# %%
pip install kivy
# Out:
# ...
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.5 MB 715.9 kB/s eta 0:00:06
#    ---- ----------------------------------- 0.5/4.5 MB 715.9 kB/s eta 0:00:06
#    ------ --------------------------------- 0.8/4.5 MB 742.0 kB/s eta 0:00:06
#    --------- ------------------------------ 1.0/4.5 MB 756.1 kB/s eta 0:00:05
#    --------- ------------------------------ 1.0/4.5 MB 756.1 kB/s eta 0:00:05
#    ----------- ---------------------------- 1.3/4.5 MB 752.7 kB/s eta 0:00:05
#    ----------- ---------------------------- 1.3/4.5 MB 752.7 kB/s eta 0:00:05
#    ------------- -------------------------- 1.6/4.5 MB 747.2 kB/s eta 0:00:04
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 import PyQt5 as pq
# ----> 2 pq.test()
#
# AttributeError: module 'PyQt5' has no attribute 'test'
